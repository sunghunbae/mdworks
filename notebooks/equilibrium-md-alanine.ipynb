# %%
from openmmtools.testsystems import AlanineDipeptideExplicit
from mdworks.protocol import Equilibrium
from pathlib import Path
import mdworks

mdworks.__version__
# Out:
# Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
#
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************
# '0.3.1'

# %%
alanine = AlanineDipeptideExplicit()
md = Equilibrium(complex=alanine, workdir=Path("/home/shbae/bit/mdworks/notebooks/alanine"))
md.stages
# Out:
# 2026-02-04 16:53:INFO:mdworks.multistage:mdworks 0.3.1
# 2026-02-04 16:53:INFO:mdworks.multistage:openff-toolkit 0.18.0
# 2026-02-04 16:53:INFO:mdworks.multistage:OpenMM platform= CUDA devices= 0
# 2026-02-04 16:53:INFO:mdworks.multistage:workdir= /home/shbae/bit/mdworks/notebooks/alanine
# 2026-02-04 16:53:INFO:mdworks.multistage:prefix= AlanineDipeptideExplicit
# 2026-02-04 16:53:INFO:mdworks.multistage:Simulation created Atoms: 2269, Residues: 752, Chains: 1, Constraints: 2259
# 2026-02-04 16:53:INFO:mdworks.multistage:Parameters: k
# 2026-02-04 16:53:INFO:mdworks.multistage:Force 0: HarmonicBondForce
# 2026-02-04 16:53:INFO:mdworks.multistage:Force 1: HarmonicAngleForce
# 2026-02-04 16:53:INFO:mdworks.multistage:Force 2: PeriodicTorsionForce
# 2026-02-04 16:53:INFO:mdworks.multistage:Force 3: NonbondedForce
# 2026-02-04 16:53:INFO:mdworks.multistage:Force 4: CMMotionRemover
# 2026-02-04 16:53:INFO:mdworks.multistage:Force 5: CustomExternalForce posres (k= 1000.0 KJ/mol/nm^2)
# [{'tag': '0_min', 'maxiter': 5000, 'tolerance': 0.1, 'interval': 10},
#  {'tag': '1_nvt_cold',
#   'description': 'NVT 100 ps at 10 K with positional restraints and a high friction coefficient',
#   't': (100.0, 1.0),
#   'T': 10,
#   'k': 1000,
#   'friction': 5,
#   'interval': 1000},
#  {'tag': '2_nvt_warm',
#   'description': 'NVT 145 ps with heating gradually while maintaining positional restraints',
#   't': (145.0, 1.0),
#   'T': (10.0, 300.0, 10.0),
#   'k': 1000.0,
#   'friction': 1,
#   'interval': 1000},
#  {'tag': '3_npt_posres',
#   'description': 'NPT 300 ps at 300.0 K with releasing positional restraints gradually',
#   't': (300.0, 1.0),
#   'T': 300.0,
#   'k': (1000.0, 0, -20),
#   'friction': 1,
#   'frequency': 50,
#   'interval': 1000},
#  {'tag': '4_npt_free',
#   'description': 'NPT 500 ps at 300.0 K without positional restraints',
#   't': (500.0, 2.0),
#   'T': 300.0,
#   'k': 0.0,
#   'friction': 1,
#   'frequency': 50,
#   'interval': 1000},
#  {'tag': '5_prod',
#   'description': 'NPT 10.0 ns at 300.0 K (production)',
#   't': (10000.0, 4.0),
#   'T': 300.0,
#   'k': 0.0,
#   'friction': 1,
#   'frequency': 50,
#   'state_data_interval': 100.0,
#   'checkpoint_interval': 100.0,
#   'trajectory_interval': 100.0}]

# %%
md.run()
# Out:
# 2026-02-04 16:53:INFO:mdworks.multistage:(0) Energy Minimization
# 2026-02-04 16:53:INFO:mdworks.multistage:(1) NVT (T= 10 K, posres_k= 1000 kJ/mol/nm**2, friction= 5 1/ps)
# 2026-02-04 16:53:INFO:mdworks.multistage:    t= 100.0 ps, dt= 1.0 fs, steps= 100.0K
# 2026-02-04 16:53:INFO:mdworks.multistage:velocities set from a Maxwell-Boltzmann distribution at 10 K
# 2026-02-04 16:53:INFO:mdworks.multistage:posres k= 1000.0 KJ/mol/nm^2
# 2026-02-04 16:53:INFO:mdworks.multistage:(2) NVT (T= 10.0 -> 300.0 K, posres_k= 1000.0 kJ/mol/nm**2, friction= 1 1/ps)
# 2026-02-04 16:53:INFO:mdworks.multistage:    t= 145.0 ps, dt= 1.0 fs, steps= 145.0K
# 2026-02-04 16:53:INFO:mdworks.multistage:velocities set from a Maxwell-Boltzmann distribution at 10.0 K
# 2026-02-04 16:53:INFO:mdworks.multistage:posres k= 1000.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:(3) NPT (T= 300.0 K, posres_k= 1000.0 -> 0 kJ/mol/nm**2, friction= 1 1/ps)
# 2026-02-04 16:54:INFO:mdworks.multistage:    t= 300.0 ps, dt= 1.0 fs, steps= 300.0K
# 2026-02-04 16:54:INFO:mdworks.multistage:Barostat (MonteCarloBarostat, frequency= 50) added
# 2026-02-04 16:54:INFO:mdworks.multistage:velocities set from a Maxwell-Boltzmann distribution at 300.0 K
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k= 1000.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  980.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  960.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  940.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  920.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  900.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  880.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  860.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  840.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  820.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  800.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  780.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  760.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  740.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  720.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  700.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  680.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  660.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  640.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  620.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  600.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  580.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  560.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  540.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  520.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  500.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  480.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  460.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  440.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  420.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  400.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  380.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  360.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  340.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  320.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  300.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  280.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  260.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  240.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  220.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  200.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  180.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  160.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  140.0 KJ/mol/nm^2
# 2026-02-04 16:54:INFO:mdworks.multistage:posres k=  120.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=  100.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=   80.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=   60.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=   40.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=   20.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=    0.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:(4) NPT (T= 300.0 K, posres_k= 0 kJ/mol/nm**2, friction= 1 1/ps)
# 2026-02-04 16:55:INFO:mdworks.multistage:    t= 500.0 ps, dt= 2.0 fs, steps= 250.0K
# 2026-02-04 16:55:INFO:mdworks.multistage:Barostat (MonteCarloBarostat) exists: not adding a new one.
# 2026-02-04 16:55:INFO:mdworks.multistage:posres k=    0.0 KJ/mol/nm^2
# 2026-02-04 16:55:INFO:mdworks.multistage:(5) NPT production (T= 300.0 K)
# 2026-02-04 16:55:INFO:mdworks.multistage:    t= 10000.0 ps, dt= 4.0 fs, steps= 2500.0K
# 2026-02-04 16:55:INFO:mdworks.multistage:    state data interval 100.0 ps
# 2026-02-04 16:55:INFO:mdworks.multistage:    checkpoint interval 100.0 ps
# 2026-02-04 16:55:INFO:mdworks.multistage:    trajectory interval 100.0 ps
# 2026-02-04 16:55:INFO:mdworks.multistage:    trajectory frames 100
# 2026-02-04 16:55:INFO:mdworks.multistage:Switching to HMR system for timestep of 4 fs
# 2026-02-04 16:55:INFO:mdworks.multistage:Simulation re-created with HMR Atoms: 2269, Residues: 752, Chains: 1, Constraints: 2259
# 2026-02-04 16:55:INFO:mdworks.multistage:Force 0: HarmonicBondForce
# 2026-02-04 16:55:INFO:mdworks.multistage:Force 1: HarmonicAngleForce
# 2026-02-04 16:55:INFO:mdworks.multistage:Force 2: PeriodicTorsionForce
# 2026-02-04 16:55:INFO:mdworks.multistage:Force 3: NonbondedForce
# 2026-02-04 16:55:INFO:mdworks.multistage:Force 4: CMMotionRemover
# 2026-02-04 16:55:INFO:mdworks.multistage:Force 5: CustomExternalForce posres (k= 1000.0 KJ/mol/nm^2)
# 2026-02-04 16:55:INFO:mdworks.multistage:Energy minimized
# 2026-02-04 16:55:INFO:mdworks.multistage:Velocities set from a Maxwell-Boltzmann distribution at 300.0 K
# 2026-02-04 16:55:INFO:mdworks.multistage:Barostat (MonteCarloBarostat, frequency= 50.0) added
# 2026-02-04 16:55:INFO:mdworks.multistage:Checkpoint saved to /home/shbae/bit/mdworks/notebooks/alanine/AlanineDipeptideExplicit_hmr.cpt
# 2026-02-04 17:02:INFO:mdworks.protocol.equilibrium:Simulation complete!
# 2026-02-04 17:02:INFO:mdworks.protocol.equilibrium:Trajectory saved to AlanineDipeptideExplicit.dcd
# 2026-02-04 17:02:INFO:mdworks.protocol.equilibrium:The final structure has been written to AlanineDipeptideExplicit_FINAL.pdb
